# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (0.116.0)
# Requirement already satisfied: python-dotenv in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: sniffio in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: httpcore==1.* in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: certifi in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: h11>=0.16 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/subhadeepghoshal/Code/01 learn/anthropic/platform-101-python/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# %%
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# %%
def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
messages = []

# %%
# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# %%
# Get Claude's response
answer = chat(messages)

# %%
# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# %%
# Add a follow-up question
add_user_message(messages, "Write another sentence")

# %%
# Get the follow-up response with full context
final_answer = chat(messages)

# %%
final_answer
# Out:
# 'Unlike classical bits, which represent either a 0 or a 1, quantum computers use qubits that can exist in multiple states simultaneously, enabling them to explore many possible solutions at once.'

# %%
add_user_message(messages, "Write another sentence")

# %%
final_answer = chat(messages)

# %%
final_answer
# Out:
# 'Unlike classical bits that represent either 0 or 1, quantum computers use qubits that can exist in multiple states simultaneously, enabling them to explore many possible solutions in parallel.'

# %%
add_assistant_message(messages, final_answer)

# %%
add_user_message(messages, "Write another sentence")

# %%
final_answer = chat(messages)

# %%
final_answer
# Out:
# 'This parallel processing power makes quantum computers particularly promising for tasks like cryptography, drug discovery, optimization problems, and simulating complex molecular or physical systems.'
