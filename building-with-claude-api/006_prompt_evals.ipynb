# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return next(block.text for block in message.content if block.type == "text")

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
print(json.dumps(dataset, indent=2))

# %%
with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a Python function that parses an S3 bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Parse an AWS S3 bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): An S3 URI in the format 's3://bucket-name/key/path'\n    \n    Returns:\n        str: The bucket name\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \n    Example:\n        >>> parse_s3_bucket_name('s3://my-bucket/folder/file.txt')\n        'my-bucket'\n    \"\"\"\n    if not isinstance(s3_uri, str):\n        raise ValueError(\"S3 URI must be a string\")\n    \n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"S3 URI must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Split by '/' and get the first part (bucket name)\n    bucket_name = uri_without_prefix.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n```\n\n## Usage Examples\n\n```python\n# Basic usage\nprint(parse_s3_bucket_name('s3://my-bucket/folder/file.txt'))\n# Output: my-bucket\n\nprint(parse_s3_bucket_name('s3://my-bucket/'))\n# Output: my-bucket\n\nprint(parse_s3_bucket_name('s3://my-bucket'))\n# Output: my-bucket\n\n# With complex paths\nprint(parse_s3_bucket_name('s3://my-data-bucket/path/to/nested/file.json'))\n# Output: my-data-bucket\n```\n\n## Alternative Implementation (Using urllib.parse)\n\nHere's a more robust version using Python's built-in `urllib.parse`:\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name_v2(s3_uri: str) -> str:\n    \"\"\"\n    Parse an AWS S3 bucket name from an S3 URI using urllib.parse.\n    \n    Args:\n        s3_uri (str): An S3 URI in the format 's3://bucket-name/key/path'\n    \n    Returns:\n        str: The bucket name\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not isinstance(s3_uri, str):\n        raise ValueError(\"S3 URI must be a string\")\n    \n    parsed = urlparse(s3_uri)\n    \n    if parsed.scheme != 's3':\n        raise ValueError(\"S3 URI must start with 's3://'\")\n    \n    bucket_name = parsed.netloc\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n```\n\n## Unit Tests\n\n```python\nimport pytest\n\ndef test_parse_s3_bucket_name():\n    # Valid cases\n    assert parse_s3_bucket_name('s3://my-bucket/folder/file.txt') == 'my-bucket'\n    assert parse_s3_bucket_name('s3://my-bucket/') == 'my-bucket'\n    assert parse_s3_bucket_name('s3://my-bucket') == 'my-bucket'\n    assert parse_s3_bucket_name('s3://bucket123/path/to/file') == 'bucket123'\n    \n    # Invalid cases\n    with pytest.raises(ValueError):\n        parse_s3_bucket_name('https://my-bucket/file')\n    \n    with pytest.raises(ValueError):\n        parse_s3_bucket_name('s3://')\n    \n    with pytest.raises(ValueError):\n        parse_s3_bucket_name(123)\n```\n\n## Comparison of Approaches\n\n| Approach | Pros | Cons",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and returns just the bucket name."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for S3 Read-Only Access\n\nHere's a JSON object that grants read-only access to all objects in the S3 bucket named 'my-data-bucket':\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Explanation:\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | AWS policy language version (always \"2012-10-17\") |\n| **Statement 1** | Grants permissions to read objects in the bucket |\n| `GetObject` | Allows reading objects |\n| `GetObjectVersion` | Allows reading specific versions of objects |\n| `Resource: /*` | Applies to all objects in the bucket |\n| **Statement 2** | Grants permissions to list and inspect the bucket |\n| `ListBucket` | Allows listing bucket contents |\n| `GetBucketVersioning` | Allows checking versioning status |\n| `Resource: (no /*)` | Applies to the bucket itself |\n\nThis policy provides complete read-only access while preventing any write, delete, or administrative operations.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Security Group ID Regex Validator\n\nHere's the regular expression to validate AWS EC2 security group IDs:\n\n```regex\n^sg-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string (anchor) |\n| `sg-` | Literal prefix \"sg-\" |\n| `[0-9a-f]` | Character class for hexadecimal digits (0-9, a-f) |\n| `{17}` | Exactly 17 hexadecimal characters |\n| `$` | End of string (anchor) |\n\n## Usage Examples\n\n### JavaScript\n```javascript\nconst sgRegex = /^sg-[0-9a-f]{17}$/;\n\n// Valid examples\nconsole.log(sgRegex.test('sg-0a1b2c3d4e5f6a7b8'));  // true\nconsole.log(sgRegex.test('sg-12345678901234abc'));   // true\n\n// Invalid examples\nconsole.log(sgRegex.test('sg-0a1b2c3d4e5f6g7h8'));   // false (contains 'g' and 'h')\nconsole.log(sgRegex.test('sg-0a1b2c3d4e5f6a7'));     // false (only 16 chars)\nconsole.log(sgRegex.test('0a1b2c3d4e5f6a7b8'));      // false (missing 'sg-')\n```\n\n### Python\n```python\nimport re\n\nsg_pattern = r'^sg-[0-9a-f]{17}$'\n\n# Valid\nprint(re.match(sg_pattern, 'sg-0a1b2c3d4e5f6a7b8'))  # Match object (True)\n\n# Invalid\nprint(re.match(sg_pattern, 'sg-0a1b2c3d4e5f6g7h8'))  # None (False)\n```\n\n## Case Sensitivity Note\n\nAWS security group IDs use **lowercase** hexadecimal characters. If you need to support uppercase as well, use:\n\n```regex\n^sg-[0-9a-fA-F]{17}$\n```",
#     "test_case": {
#       "task": "Write a regular expression that validates an AWS EC2 security group ID, which follows the format 'sg-' followed by exactly 17 hexadecimal characters (e.g., 'sg-0a1b2c3d4e5f6g7h8')."
#     },
#     "score": 10
#   }
# ]
